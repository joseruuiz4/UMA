# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np



df = pd.read_csv("./bmw.csv")

# %% [markdown]
# **Ejercicio 1:**
# Representa la función f(x) = sin(x)+cos(x) en el intervalo [0,2*pi].

# %%
x = np.linspace(0, 2*np.pi, 100)

y = np.sin(x) + np.cos(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfica de f(x) = sin(x) + cos(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Ejercicio 2:**
# Representa las funciones f(x) = sin(x), g(x)=log(1+x) en el intervalo [0,2*pi], tomando 100 puntos igualmente espaciados en dicho intervalo.

# %%
y_sin = np.sin(x)
y_log = np.log(1 + x)

plt.plot(x, y_sin, label='f(x) = sin(x)')
plt.plot(x, y_log, label='g(x) = log(1+x)')
plt.xlabel('x')
plt.ylabel('f(x), g(x)')
plt.title('Gráficas de f(x) = sin(x) y g(x) = log(1+x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Ejercicio 3:**
# Crea un gráfico de barras que muestre las frecuencias de los distintos valores del atributo model de la base de datos.

# %%
model= df['model'].value_counts()


plt.bar(model.index, model.values)
plt.xlabel('Modelo')
plt.ylabel('Frecuencia')
plt.title('Frecuencias de los distintos modelos')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Ejercicio 4:**
# Crea un gráfico de dispersión que muestre los precios (atributo “price”) en el eje horizontal, los kilometrajes (atributo “mileage”) en el eje vertical, y las eficiencias (atributo “mpg”) como colores.

# %%
price = df['price']
mileage = df['mileage']
mpg = df['mpg']


plt.scatter(price, mileage, c=mpg, cmap='viridis', alpha=0.5)
plt.colorbar(label='MPG')
plt.xlabel('Precio')
plt.ylabel('Kilometraje')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# **Ejercicio 5:**
# Crea un histograma que muestre los precios (atributo “price”) de la base de datos.

# %%
price = df['price']


plt.hist(price, bins=60, color='red', edgecolor='black')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de precios')
plt.grid(True)
plt.show()

# %% [markdown]
# **Ejercicio 6:**
# Considera la siguiente función, que calcula valores enteros entre 0 y 255 para dibujar el fractal de Mandelbrot, siendo a y b números en coma flotante que representan la parte real y la parte imaginaria de un número complejo, respectivamente.

# %%
min_real = -2
max_real = 1
min_imaginaria = -1
max_imaginaria = 1

mapa_calor = np.zeros((400, 600))

MAXIMO_ITERACIONES = 80

def mandelbrot(a, b):
    c = complex(a, b)
    z = 0
    n = 0
    while abs(z) <= 2 and n < MAXIMO_ITERACIONES:
        z = z * z + c
        n += 1
    color_pixel = 255 - int(n * 255 / MAXIMO_ITERACIONES)
    return color_pixel


for y in range(400):
    for x in range(600):
        real = min_real + (max_real - min_real) * x / (600 - 1)
        imaginaria = min_imaginaria + (max_imaginaria - min_imaginaria) * y / (400 - 1)
        mapa_calor[y, x] = mandelbrot(real, imaginaria)


plt.imshow(mapa_calor, cmap='hot', extent=[min_real, max_real, min_imaginaria, max_imaginaria])
plt.colorbar(label='Iteraciones')
plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginaria')
plt.title('Mapa de calor del fractal de Mandelbrot')
plt.show()
